# %%
import numpy as np

import pandas as pd

from pandas import Series,DataFrame

from pandas import read_html

# %%
url ="https://en.wikipedia.org/wiki/List_of_U.S._states_and_territories_by_GDP"

# %%
dframe_list=pd.io.html.read_html(url)

# %%
dframe=dframe_list[2]

# %%
dframe
# Out:
#        0                1                         2              3  \
# 0   Rank  Rank(50 states)        State or territory           2017
# 1      —                —             United States  19,263,350[B]
# 2      1                1                California        2746873
# 3      2                2                     Texas        1696206
# 4      3                3                  New York        1547116
# 5      4                4                   Florida         967337
# 6      5                5                  Illinois         820362
# 7      6                6              Pennsylvania         752071
# 8      7                7                      Ohio         649127
# 9      8                8                New Jersey         591743
# 10     9                9                   Georgia         554269
# 11    10               10            North Carolina         538291
# 12    11               11             Massachusetts         527455
# ...

# %%
DataFrame(dframe,columns=[2,3]).rename(columns=["States","GDP"])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-8-5cdeea0f5e3e> in <module>()
# ----> 1 DataFrame(dframe,columns=[2,3]).rename(columns=["States","GDP"])
#
# ~\Anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     184         @wraps(func)
#     185         def wrapper(*args, **kwargs):
# --> 186             return func(*args, **kwargs)
#     187
#     188         if not PY2:
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in rename(self, *args, **kwargs)
#    3776         kwargs.pop('axis', None)
#    3777         kwargs.pop('mapper', None)
# -> 3778         return super(DataFrame, self).rename(**kwargs)
#    3779
#    3780     @Substitution(**_shared_doc_kwargs)
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in rename(self, *args, **kwargs)
# ...
